# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
df = pd.read_csv(r"C:\Users\Home\Downloads\dst-3.0_16_1_hh_database.csv", encoding='utf-8', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь

df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь

df['Образование'] = df['Образование и ВУЗ'].apply(
    lambda x: 'высшее' if 'Высшее' in ' '.join(x.split()[:3]) else
              'неоконченное высшее' if 'Неоконченное высшее' in ' '.join(x.split()[:3]) else
              'среднее специальное' if 'Среднее специальное' in ' '.join(x.split()[:3]) else
              'среднее' if 'Среднее' in ' '.join(x.split()[:3]) else
              'другое'
)
print(df['Образование'].unique())

df = df.drop(columns=['Образование и ВУЗ'])

df.head()
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# ...

# %%
df[df['Образование'] == 'среднее'].shape[0]
# Out:
# 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
df[['Пол', 'Возраст']] = df['Пол, возраст'].str.split(' , ', expand=True)[[0, 1]]
df['Пол'] = df['Пол'].apply(lambda x: 'М' if x == 'Мужчина' else 'Ж')
df['Возраст'] = df['Возраст'].str.extract('(\d+)').astype(int)

df = df.drop(columns=['Пол, возраст'])

print(df['Пол'].unique())
print(df['Возраст'].head())

df.head()
# Out:
# <>:4: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# <>:4: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# C:\Users\Home\AppData\Local\Temp\ipykernel_14728\4042106881.py:4: SyntaxWarning:
#
# invalid escape sequence '\d'
# ['М' 'Ж']
# 0    39
# 1    60
# 2    36
# 3    38
# 4    26
# Name: Возраст, dtype: int64
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# ...

# %%
# 1. Процент женских резюме
female_percentage = (df[df['Пол'] == 'Ж'].shape[0] / df.shape[0]) * 100
female_percentage = round(female_percentage, 2)

# 2. Средний возраст соискателей
average_age = round(df['Возраст'].mean(), 1)

print(f"Процент женских резюме: {female_percentage}%")
print(f"Средний возраст соискателей: {average_age}")
# Out:
# Процент женских резюме: 19.07%
# Средний возраст соискателей: 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
# Функция для вычисления опыта в месяцах
def experience_in_months(series):
    is_na = series.isna()
    hidden_na = series.str.contains('Не указано', na=False)
    
    years = series.str.extract(r'(\d+)\s*(?:год|года|лет)')[0].astype(float).fillna(0)
    
    months = series.str.extract(r'(\d+)\s*месяц')[0].astype(float).fillna(0)
    
    total_months = years * 12 + months
    
    total_months[is_na | hidden_na] = np.nan
    
    return total_months

df['Опыт работы (месяц)'] = experience_in_months(df['Опыт работы'])

df = df.drop(columns=['Опыт работы'])

display(df.tail(10))
display(df.info())
# Out:
#                  ЗП                          Ищет работу на должность:  \
# 44734    85000 руб.  Технический специалист со знанием нем/англ языков
# 44735    70000 руб.                    Тестировщик ПО Работу уже нашёл
# 44736  800 бел.руб.   мастер по ремонту, водитель,продавец-консультант
# 44737    70000 руб.                             Руководитель IT-отдела
# 44738   150000 руб.                                   head of helpdesk
# 44739    50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740    39000 руб.             Системный администратор, IT-специалист
# 44741    40000 руб.                         Аналитик данных, Математик
# 44742    20000 руб.                                   Контент-менеджер
# 44743   120000 руб.                               Руководитель проекта
#
#                             Город, переезд, командировки  \
# 44734  Москва ,  м. Коломенская , готов к переезду , ...
# 44735  Москва ,  м. Сокольники , не готов к переезду ...
# ...

# %%
median_experience = df['Опыт работы (месяц)'].median()
print(f"Медианный опыт работы (в месяцах): {median_experience}")
# Out:
# Медианный опыт работы (в месяцах): 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
def get_city(arg):
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород',
                      'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 
                      'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград'
                     ]
    city = arg.split(' , ')[0]
    if (city == 'Москва') or (city == 'Санкт-Петербург'):
        return city
    elif city in million_cities:
        return 'город миллионник'
    else:
        return 'другие'
    
def get_ready_to_move(arg):
    if ('не готов к переезду' in arg) or ('не готова к переезду' in arg):
        return False
    elif 'хочу' in arg:
        return True
    else:
        return True
    
def get_ready_for_bisiness_trips(arg):
    if ('командировка' in arg):
        if ('не готов к командировкам' in arg) or('не готова к командировкам' in arg):
            return False
        else: 
            
            return True
    else:
        return False
    
df['Город'] = df['Город, переезд, командировки'].apply(get_city)
df['Готовность к переезду'] = df['Город, переезд, командировки'].apply(get_ready_to_move)
df['Готовность к командировкам'] = df['Город, переезд, командировки'].apply(get_ready_for_bisiness_trips)
df = df.drop('Город, переезд, командировки', axis=1)
print(round(df['Город'].value_counts(normalize=True)['Санкт-Петербург'] * 100)) 
print(round(df[
    df['Готовность к переезду'] & df['Готовность к командировкам']
].shape[0] / df.shape[0] *100))
# Out:
# 11
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
employment_dummies = df['Занятость'].str.get_dummies(sep=', ').astype(bool)
schedule_dummies = df['График'].str.get_dummies(sep=', ').astype(bool)

df = pd.concat([df, employment_dummies, schedule_dummies], axis=1)
df = df.drop(columns=['Занятость', 'График'])
df = df.loc[:, ~df.columns.duplicated()]

df.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# ...

# %%
project_and_volunteer = df[(df['проектная работа'] == True) & (df['волонтерство'] == True)].shape[0]

# Подсчет количества людей, которые хотят работать вахтовым методом и с гибким графиком
shift_and_flexible = df[(df['вахтовый метод'] == True) & (df['гибкий график'] == True)].shape[0]

# Вывод результатов
results = {
    "Людей, ищущих проектную работу и волонтерство": project_and_volunteer,
    "Людей, которые хотят работать вахтовым методом и с гибким графиком": shift_and_flexible
}

results
# Out:
# {'Людей, ищущих проектную работу и волонтерство': 436,
#  'Людей, которые хотят работать вахтовым методом и с гибким графиком': 2311}

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь
df2 = pd.read_csv(r"C:\Users\Home\Downloads\ExchangeRates\ExchangeRates.csv")

df['ЗП'] = df['ЗП'].str.strip()

df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме']).dt.date
df2['date'] = pd.to_datetime(df2['date'], format='%d/%m/%y').dt.date

currency_mapping = {
    'грн.': 'UAH', 'USD': 'USD', 'EUR': 'EUR', 'бел.руб.': 'BYN',
    'KGS': 'KGS', 'сум': 'UZS', 'AZN': 'AZN', 'KZT': 'KZT', 'руб.': 'RUB'
}

df['ЗП_сумма'] = df['ЗП'].str.extract(r'(\d+[.,]?\d*)').replace(',', '.', regex=True).astype(float)

df['ЗП_валюта'] = df['ЗП'].str.extract(r'([а-яА-Я.]+|[A-Z]+)')
df['ЗП_валюта'] = df['ЗП_валюта'].map(currency_mapping)

unparsable_rows = df[df['ЗП_сумма'].isna() | df['ЗП_валюта'].isna()]

df = df.merge(df2, how='left', left_on=['Обновление резюме', 'ЗП_валюта'],
              right_on=['date', 'currency'], suffixes=('', '_currency'))

df.loc[df['ЗП_валюта'] == 'RUB', 'close'] = 1
df.loc[df['ЗП_валюта'] == 'RUB', 'proportion'] = 1

df['ЗП (руб)'] = (df['ЗП_сумма'] * df['close'] / df['proportion']).round(2)

df = df.drop(columns=['ЗП', 'ЗП_сумма', 'ЗП_валюта', 'date', 'currency', 'close', 'proportion', 'per', 'time', 'vol'])
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_14728\2041148773.py:8: UserWarning:
#
# Parsing dates in %d.%m.%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
# Уникальные значения валюты: ['RUB' 'BYN' 'KZT' 'EUR' 'USD' 'UAH' 'UZS' 'KGS' 'AZN']
# Необработанные строки:
# Empty DataFrame
# Columns: [ЗП]
# Index: []
# Пропуски в 'ЗП (руб)': 0

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
import plotly.io as pio
pio.renderers.default = "notebook" 
pio.renderers.default = "browser"

if 'Возраст' in df.columns:
    plt.figure(figsize=(10, 6))
    plt.hist(df['Возраст'], bins=30, edgecolor='black', alpha=0.7)
    plt.title('Распределение возраста соискателей')
    plt.xlabel('Возраст')
    plt.ylabel('Количество соискателей')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

    fig = px.box(df, y="Возраст", title="Коробчатая диаграмма возраста соискателей")
    fig.show()

    mode_age = df['Возраст'].mode()[0]
    min_age = df['Возраст'].min()
    max_age = df['Возраст'].max()

    age_percentiles = df['Возраст'].quantile([0.25, 0.75])
    lower_bound, upper_bound = age_percentiles.iloc[0], age_percentiles.iloc[1]

    description = {
        "Мода": mode_age,
        "Минимальный возраст": min_age,
        "Максимальный возраст": max_age,
        "Интервал большинства соискателей (25-75 перцентиль)": (lower_bound, upper_bound)
    }

    description
else:
    "Столбец 'Возраст' не найден в данных."

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Мода распределения возраста**:
#    - Гистограмма показывает, что модальное значение (наиболее часто встречающееся) находится в диапазоне **30–31 года**. Это подтверждается плотностью значений в этом интервале.
#
# 2. **Предельные значения признака**:
#    - Возраст соискателей варьируется от **14 до 100 лет**, что видно из коробчатой диаграммы и гистограммы.
#    - Большинство соискателей находятся в возрасте **от 27 до 36 лет**, что соответствует межквартильному диапазону (между первым квартилем Q1 = 27 и третьим квартилем Q3 = 36).
#
# 3. **Аномалии**:
#    - Возраст **14 лет** можно считать аномалией, так как он слишком мал для полноценного соискателя.
#    - Возраст **100 лет** также выглядит как выброс и может быть ошибкой или редким исключением.
#    - Коробчатая диаграмма показывает выбросы, которые начинаются примерно с 49 лет (значения выше верхней границы усов).

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
plt.figure(figsize=(10, 6))
plt.hist(df['Опыт работы (месяц)'].dropna(), bins=30, edgecolor='black', alpha=0.7)
plt.title('Распределение опыта работы (в месяцах)')
plt.xlabel('Опыт работы (месяц)')
plt.ylabel('Количество соискателей')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

fig = px.box(df, y='Опыт работы (месяц)', points="all", title="Коробчатая диаграмма опыта работы (в месяцах)")
fig.show()

experience_mode = df['Опыт работы (месяц)'].mode().iloc[0] 
experience_min = df['Опыт работы (месяц)'].min()
experience_max = df['Опыт работы (месяц)'].max()
experience_median = df['Опыт работы (месяц)'].median()

experience_mode, experience_min, experience_max, experience_median
# Out:
# (np.float64(81.0), np.float64(1.0), np.float64(24230.0), np.float64(100.0))

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Мода распределения**:
#    - Большинство соискателей имеет опыт работы около **0-1 месяца**. Это видно по высокой плотности данных в этом диапазоне на гистограмме.
#
# 2. **Максимальное значение опыта работы**:
#    - Максимальное значение опыта работы составляет **24230 месяцев**, что эквивалентно примерно 2019 годам. Это явно является аномалией.
#
# 3. **Основной диапазон значений**:
#    - Большинство значений опыта работы находится в диапазоне от **0 до 302 месяцев** (по данным коробчатой диаграммы).
#
# 4. **Аномалии**:
#    - Значения выше 302 месяцев можно считать аномальными, так как они выходят за пределы "усов" на коробчатой диаграмме.
#
# 5. **Распределение**:
#    - Распределение сильно смещено влево, что свидетельствует о большом количестве соискателей с небольшим опытом работы.
#
# Максимальный опыт работы в таблице действительно составляет **24230 месяцев**, что является нереалистичным и должно быть очищено или обработано как выброс.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
log_salary = np.log1p(df['ЗП (руб)'])

plt.figure(figsize=(10, 6))
plt.hist(log_salary, bins=20, edgecolor='black', alpha=0.7)
plt.title("Распределение заработной платы (в логарифмическом масштабе)")
plt.xlabel("Логарифм заработной платы")
plt.ylabel("Количество соискателей")
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df['ЗП (руб)'], bins=50, range=(0, 200000), edgecolor='black', alpha=0.7)
plt.title("Распределение заработной платы (в рублях)")
plt.xlabel("Заработная плата (рубли)")
plt.ylabel("Количество соискателей")
plt.show()

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Мода распределения**:
#    - Заработная плата большинства соискателей сосредоточена в диапазоне от **30,000 до 50,000 рублей**.
#
# 2. **Предельные значения**:
#    - Минимальная зарплата: 1 рубль.
#    - Максимальная зарплата: около **24 миллионов рублей**.
#
# 3. **Аномалии**:
#    - Значения выше **1 миллиона рублей** выглядят как выбросы и могут считаться аномальными, поскольку они значительно превышают верхнюю границу (upper fence).
#
# 4. **Распределение**:
#    - Большинство значений находятся в пределах **30,000–100,000 рублей**.
#    - Наблюдается сильная асимметрия распределения с длинным "хвостом" в сторону высоких зарплат.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
filtered_data = df[df['ЗП (руб)'] < 1_000_000]

education_salary_median = filtered_data.groupby('Образование')['ЗП (руб)'].median()

plt.figure(figsize=(10, 6))
education_salary_median.sort_values(ascending=False).plot(kind='bar', edgecolor='black', alpha=0.7)
plt.title('Медианная желаемая зарплата в зависимости от уровня образования', fontsize=14)
plt.ylabel('Медианная зарплата (руб)', fontsize=12)
plt.xlabel('Уровень образования', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

education_salary_median
# Out:
# Образование
# высшее                 60000.0
# неоконченное высшее    50000.0
# среднее                40000.0
# среднее специальное    40000.0
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Наибольший уровень желаемой заработной платы** наблюдается у соискателей с высшим образованием. Это ожидаемо, так как высшее образование часто связано с более высокой квалификацией и, соответственно, большей зарплатой.
#
# 2. **Средний уровень желаемой заработной платы** у соискателей с неоконченным высшим образованием ниже, чем у тех, кто получил высшее образование, но выше, чем у соискателей со средним и средним специальным образованием.
#
# 3. **Наименьший уровень желаемой заработной платы** наблюдается у соискателей со средним и средним специальным образованием. Это подчеркивает важность дополнительного образования для повышения уровня желаемого заработка.
#
# 4. **Роль образования при прогнозировании зарплаты**:
#    - Образование оказывает значительное влияние на уровень желаемой заработной платы, так как соискатели с более высоким уровнем образования стремятся к более высокооплачиваемым должностям.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
filtered_df = df[df['ЗП (руб)'] < 1_000_000]

plt.figure(figsize=(12, 6))
sns.boxplot(data=filtered_df, x='Город', y='ЗП (руб)', order=['Москва', 'Санкт-Петербург', 'город-миллионник', 'другие'])

plt.title('Распределение желаемой заработной платы в зависимости от города')
plt.xlabel('Город')
plt.ylabel('ЗП (руб)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Медианный уровень желаемой заработной платы:**
#    - Соискатели из Москвы имеют самый высокий медианный уровень заработной платы по сравнению с другими городами.
#    - Санкт-Петербург занимает второе место, но медианная заработная плата здесь немного ниже, чем в Москве.
#    - Соискатели из городов-миллионников и других городов имеют примерно одинаковый медианный уровень заработной платы, который значительно ниже, чем в Москве и Санкт-Петербурге.
#
# 2. **Размах заработной платы:**
#    - В Москве наблюдается самый широкий размах желаемой заработной платы, включая значительное количество выбросов с высокими значениями.
#    - В Санкт-Петербурге размах немного меньше, но также встречаются высокие выбросы.
#    - В городах-миллионниках и других городах размах желаемой заработной платы существенно меньше, выбросы менее выражены.
#
# 3. **Важность признака города:**
#    - Признак города явно важен при прогнозировании заработной платы, так как уровень желаемой заработной платы зависит от города проживания. Москва и Санкт-Петербург показывают явное отличие в медиане и размахе по сравнению с другими категориями городов.
#
# Вывод: уровень желаемой заработной платы варьируется в зависимости от города проживания, что указывает на необходимость учета этого признака при прогнозировании заработной платы.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
filtered_df = df[df['ЗП (руб)'] < 1_000_000] 
grouped_data = filtered_df.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()
grouped_data.plot(kind='bar', figsize=(10, 6), stacked=False)

plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.ylabel('Медианная заработная плата (руб)')
plt.xlabel('Готовность к переезду')
plt.xticks(rotation=0)
plt.legend(title='Готовность к командировкам', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ### Выводы по многоуровневой диаграмме:
#
# 1. **Зависимость заработной платы от готовности к переезду и командировкам**:
#    - Соискатели, готовые к командировкам, требуют медианно более высокую заработную плату, чем те, кто к командировкам не готов, независимо от их готовности к переезду.
#    - Медианная зарплата соискателей, готовых и к переезду, и к командировкам, выше, чем у тех, кто готов только к переезду или только к командировкам.
#
# 2. **Влияние переезда на заработную плату**:
#    - У соискателей, не готовых к командировкам, медианная зарплата выше у тех, кто готов к переезду, по сравнению с теми, кто не готов.
#    - Аналогично, среди готовых к командировкам соискателей те, кто готов к переезду, требуют медианно более высокую зарплату.
#
# 3. **Признак переезда и командировок как индикаторы желаемой зарплаты**:
#    - Готовность к переезду и командировкам свидетельствует о большей мобильности и вероятно о наличии более высоких профессиональных ожиданий, что связано с увеличением медианной желаемой зарплаты.
#
# 4. **Наибольшая медианная зарплата**:
#    - Соискатели, готовые и к переезду, и к командировкам, требуют медианно наибольшую зарплату среди всех категорий.
#
# **Резюме**:
# Признаки готовности к переезду и командировкам оказывают значительное влияние на желаемую медианную заработную плату. Это говорит о том, что эти факторы важно учитывать при прогнозировании зарплатных ожиданий.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
pivot = df.pivot_table(
    index='Образование',
    columns='Возраст',
    values='ЗП (руб)',
    aggfunc='median',
    fill_value=0
)
fig = px.imshow(
    pivot,
    aspect='auto',
    color_continuous_scale='greens',
    title='Медианная з/п по образованию и возрасту'
)
fig.show()

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Зависимость заработной платы от образования:**
#    - Соискатели с высшим образованием имеют более высокие медианные значения заработной платы по сравнению с другими категориями образования.
#    - Среднее специальное и среднее образование демонстрируют наименьшие медианные значения заработной платы.
#
# 2. **Зависимость заработной платы от возраста:**
#    - Уровень заработной платы растет с возрастом, особенно для категорий с высшим образованием. Это говорит о том, что карьерный рост и повышение заработной платы с возрастом более интенсивны для людей с высшим образованием.
#    - Начиная с определенного возраста (около 50–60 лет), рост заработной платы замедляется или даже снижается.
#
# 3. **Аномалии:**
#    - У некоторых категорий образования наблюдаются отдельные возрастные группы с аномально высокими значениями заработной платы, возможно связанные с редкими профессиональными навыками или позициями.
#
# 4. **Карьерный рост:**
#    - Наиболее интенсивный рост заработной платы наблюдается у соискателей с высшим образованием. Это указывает на то, что образование является важным фактором карьерного роста и повышения доходов.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь

df['Опыт работы (год)'] = df['Опыт работы (месяц)'] / 12

plt.figure(figsize=(10, 6))
plt.scatter(df['Возраст'], df['Опыт работы (год)'], alpha=0.5, label="Соискатели")

plt.plot([0, 100], [0, 100], color='red', linestyle='--', label="Линия: опыт работы = возраст")

plt.title("Зависимость опыта работы от возраста", fontsize=14)
plt.xlabel("Возраст (год)", fontsize=12)
plt.ylabel("Опыт работы (год)", fontsize=12)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Выводы по графикам:
#
# 1. **Основная масса точек:** Большинство точек располагается ниже линии, что соответствует нормальному соотношению возраста и опыта работы (опыт меньше возраста).
#
# 2. **Аномалии:** Есть несколько точек, которые лежат строго выше линии. Эти точки указывают на соискателей, у которых опыт работы превышает их возраст, что может быть связано с ошибками в данных или некорректным заполнением информации.
#
# 3. **Концентрация данных:** Видна концентрация точек в области, где возраст составляет от 20 до 40 лет, а опыт работы — от 0 до 20 лет, что соответствует типичной ситуации на рынке труда.
#
# Для определения количества точек выше линии:
# 1. Фильтрация данных поможет выявить точное число записей, где опыт работы превышает возраст.
# 2. По графику можно предположить, что таких точек не более десятка, но это требует точного расчета.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
# График 1: Распределение заработной платы в зависимости от возраста
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[df['ЗП (руб)'] < 1_000_000], x='Возраст', y='ЗП (руб)', showfliers=False)
plt.title('Распределение заработной платы в зависимости от возраста', fontsize=14)
plt.xlabel('Возраст', fontsize=12)
plt.ylabel('Заработная плата (руб)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# График 2: Зависимость медианной заработной платы от пола и уровня образования
pivot_table_gender_edu = df[df['ЗП (руб)'] < 1_000_000].pivot_table(
    values='ЗП (руб)', index='Пол', columns='Образование', aggfunc='median'
)

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table_gender_edu, annot=True, fmt='.0f', cmap='YlGnBu')
plt.title('Медианная заработная плата в зависимости от пола и уровня образования', fontsize=14)
plt.xlabel('Образование', fontsize=12)
plt.ylabel('Пол', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# ### Выводы по первому графику (распределение заработной платы в зависимости от возраста):
# 1. **Тренд роста заработной платы с возрастом:**
#    - На графике видно, что с увеличением возраста соискателей медианная заработная плата возрастает, достигая пика примерно в возрасте 40-50 лет.
#    - После этого зарплата стабилизируется или начинает снижаться.
#
# 2. **Разброс заработной платы:**
#    - В молодом возрасте разброс значений относительно небольшой, что может быть связано с меньшим опытом работы и стартовыми должностями.
#    - В средних возрастных категориях (30-50 лет) разброс становится значительным, что связано с вариативностью в карьере, опыте и должностях.
#    - В старших возрастных категориях разброс вновь уменьшается.
#
# 3. **Аномалии:**
#    - Видны выбросы с высокими значениями заработной платы даже для молодых возрастных групп, что может быть связано с аномальными данными или исключительными случаями (например, топ-менеджеры или редкие профессии).
#
# ---
#
# ### Выводы по второму графику (медианная зарплата в зависимости от пола и уровня образования):
# 1. **Влияние уровня образования:**
#    - Люди с высшим образованием имеют наибольшую медианную заработную плату среди всех уровней образования, как среди мужчин, так и среди женщин.
#    - Для всех категорий образование коррелирует с заработной платой: чем выше уровень образования, тем выше медианная зарплата.
#
# 2. **Разница между мужчинами и женщинами:**
#    - Мужчины во всех категориях образования получают более высокую медианную заработную плату, чем женщины.
#    - Наибольшая разница наблюдается в категории "высшее образование", где медианная зарплата мужчин превышает женскую примерно на 20,000 рублей.
#
# 3. **Меньшее влияние образования на женщин:**
#    - У женщин с "неоконченным высшим", "средним" и "средним специальным" образованием разница в зарплатах относительно небольшая, что указывает на менее выраженную корреляцию между образованием и зарплатой по сравнению с мужчинами.
#
# ---
#
# ### Общие выводы:
# 1. **Возраст и образование играют ключевую роль в заработной плате.**
# 2. **Существует явный гендерный разрыв в зарплатах, особенно для высокообразованных соискателей.**
# 3. **Для более точного анализа данных стоит учитывать возможные скрытые факторы, такие как отрасль, должность и место работы.**

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
duplicates = df[df.duplicated()]
num_duplicates = duplicates.shape[0]

df = df.drop_duplicates()

num_duplicates
# Out:
# 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
missing_values = df.isnull().sum()
df = df.drop(columns=['Опыт работы (год)'])

missing_experience = missing_values.get("Опыт работы (месяц)", 0)

missing_values, missing_experience
# Out:
# (Ищет работу на должность:            0
#  Последнее/нынешнее место работы      1
#  Последняя/нынешняя должность         2
#  Обновление резюме                    0
#  Авто                                 0
#  Образование                          0
#  Пол                                  0
#  Возраст                              0
#  Опыт работы (месяц)                170
#  Город                                0
#  Готовность к переезду                0
#  Готовность к командировкам           0
#  волонтерство                         0
#  полная занятость                     0
#  проектная работа                     0
#  стажировка                           0
#  частичная занятость                  0
#  вахтовый метод                       0
#  гибкий график                        0
#  полный день                          0
#  сменный график                       0
#  удаленная работа                     0
#  ЗП (руб)                             0
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
df = df.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

median_experience = df['Опыт работы (месяц)'].median()
df['Опыт работы (месяц)'] = df['Опыт работы (месяц)'].fillna(median_experience)

missing_info = df.isna().sum()

missing_info
# Out:
# Ищет работу на должность:          0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# Обновление резюме                  0
# Авто                               0
# Образование                        0
# Пол                                0
# Возраст                            0
# Опыт работы (месяц)                0
# Город                              0
# Готовность к переезду              0
# Готовность к командировкам         0
# волонтерство                       0
# полная занятость                   0
# проектная работа                   0
# стажировка                         0
# частичная занятость                0
# вахтовый метод                     0
# гибкий график                      0
# полный день                        0
# сменный график                     0
# удаленная работа                   0
# ЗП (руб)                           0
# dtype: int64

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
df = df[(df['ЗП (руб)'] <= 1_000_000) & (df['ЗП (руб)'] >= 1_000)]
# Out:
# Количество выбросов: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
df = df[df['Опыт работы (месяц)'] / 12 <= df['Возраст']]

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь
df['log_Возраст'] = np.log1p(df['Возраст'])

plt.figure(figsize=(10, 6))
histplot = sns.histplot(df['log_Возраст'], bins=30, kde=True, color='skyblue')

mean_log_age = df['log_Возраст'].mean()
std_log_age = df['log_Возраст'].std()

histplot.axvline(mean_log_age, color='k', linestyle='-', lw=2, label='Среднее')
histplot.axvline(mean_log_age + 3 * std_log_age, color='r', linestyle='--', lw=2, label='Граница 3 сигм (вправо)')
histplot.axvline(mean_log_age - 3 * std_log_age, color='r', linestyle='--', lw=2, label='Граница 3 сигм (влево)')
histplot.axvline(mean_log_age + 4 * std_log_age, color='orange', linestyle='--', lw=2, label='Граница 4 сигм (вправо)')

plt.title('Распределение возраста в логарифмическом масштабе')
plt.xlabel('Логарифм возраста')
plt.ylabel('Количество соискателей')
plt.legend()
plt.show()

upper_bound = mean_log_age + 4 * std_log_age
outliers = df[df['log_Возраст'] > upper_bound]

df = df[df['log_Возраст'] <= upper_bound]

print("Выбросы по возрасту:")
print(outliers[['Возраст', 'log_Возраст']])

outliers_ages = outliers['Возраст'].unique()
print("Возраст соискателей, попадающих под категорию выбросов:", outliers_ages)
# Out:
# Выбросы по возрасту:
#        Возраст  log_Возраст
# 33654      100     4.615121
# Возраст соискателей, попадающих под категорию выбросов: [100]

# %% [markdown]
# ### Подробные выводы по графику
#
# 1. **Асимметрия**:
#    - Логарифмическое распределение **асимметрично в правую сторону**, что указывает на наличие относительно небольшого количества соискателей с экстремально высоким возрастом (в логарифмическом масштабе). Это говорит о редкости соискателей с возрастами, значительно превышающими средние значения.
#
# 2. **Среднее значение и разброс**:
#    - **Среднее значение логарифма возраста** (около 3.4) соответствует среднему возрасту большинства соискателей (примерно 30 лет).
#    - Практически весь основной массив данных сосредоточен в пределах 3 сигм (примерно от 20 до 60 лет в линейной шкале).
#    - Разброс данных, выходящий за пределы 3 сигм вправо, указывает на наличие выбросов в виде возрастов 80 лет и старше.
#
# 3. **Границы метода трех сигм и послабления**:
#    - Красные линии обозначают стандартный метод трех сигм, выделяя значительное отклонение от среднего.
#    - Желтая линия на правом конце указывает на границу **четырех сигм** (послабление), чтобы учесть редкие, но возможные высокие значения возраста, которые не считаются выбросами.
#
# 4. **Выбросы и их полезность**:
#    - Выбросы находятся **справа от желтой линии (4 сигмы)** и представляют соискателей с экстремально высоким возрастом.
#    - Данные выбросы могут искажать модель прогнозирования, если их не обработать. Например, резюме людей старше 90 лет могут быть аномалиями, вызванными ошибками в данных или редкими случаями.
#
# 5. **Полезность графика**:
#    - График полезен для выявления выбросов в признаке возраста в **логарифмическом масштабе**, что позволяет лучше анализировать распределение данных с высокой правой асимметрией.
#    - Он показывает, что большинство соискателей имеет возраст в пределах от 20 до 60 лет, что соответствует основному рынку труда.
#    - График дает возможность принять обоснованное решение по удалению выбросов, которые могут быть связаны с данными о возрастах старше 80–90 лет.
